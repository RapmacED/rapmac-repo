# %%
import  pandas as pd

# %%
df = pd.read_csv('listPadels.csv')
df.head()
# Out:
#               name                                    address business_status  \
# 0   Pista de pádel     Diseminado Diseminados, 14, Villovieco     OPERATIONAL
# 1  Pistas de pádel  C. la Motilla, 4, Villagonzalo Pedernales     OPERATIONAL
# 2  Pistas de pádel  C. la Motilla, 4, Villagonzalo Pedernales     OPERATIONAL
# 3      Pista Pádel                         Unnamed Road 09390     OPERATIONAL
# 4   Pista de padel                 Calle la Iglesia, 22, Igea     OPERATIONAL
#
#     latitude  longitude
# 0  42.292934  -4.483354
# 1  42.300451  -3.739500
# 2  42.300451  -3.739500
# 3  42.095121  -3.691668
# 4  42.070266  -2.007531

# %%
df = df[~df['name'].str.contains("TC ")]

# %%
df = df[~df['name'].str.contains("TENNIS CLUB ", case=False)]

# %%
df = df[~df['name'].str.contains("T\.C\.")]

# %%
df.to_csv('listPadelsCleaned.csv', index = False)

# %%
df[df['name'].str.contains("club tennis", case = False)]
# Out:
#                                              name  \
# 40                        Club Tennis Campdevànol
# 43                        Club Tennis Campdevànol
# 46                               Club Tennis Olot
# 50                               Club Tennis Olot
# 54               Club Tennis Alt Empordà Figueres
# 55                           Club Tennis Figueres
# 59                        Club Tennis Padel Roses
# 64               Club Tennis Alt Empordà Figueres
# 65                           Club Tennis Figueres
# 70                        Club Tennis Padel Roses
# 139                      Club Tennis Santa Coloma
# 153                      Club Tennis Santa Coloma
# 922                     CLUB TENNIS FOREVER NIMES
# 2921  Royal Baudouin Club Tennis | Tennis & Padel
# 2939  Royal Baudouin Club Tennis | Tennis & Padel
# 3100  Royal Baudouin Club Tennis | Tennis & Padel
# 3109  Royal Baudouin Club Tennis | Tennis & Padel
#
# ...
