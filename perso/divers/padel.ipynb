# %%
import os
import googlemaps
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 import googlemaps
#       3 from datetime import datetime
#
# ModuleNotFoundError: No module named 'googlemaps'

# %%
pip list
# Out:
# Package                  Version
# ------------------------ ------------
# anyio                    3.6.2
# appnope                  0.1.3
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# arrow                    1.2.3
# asttokens                2.2.1
# async-generator          1.10
# attrs                    22.1.0
# backcall                 0.2.0
# beautifulsoup4           4.11.1
# bleach                   5.0.1
# CacheControl             0.12.11
# cachetools               5.2.0
# certifi                  2022.9.24
# cffi                     1.15.1
# charset-normalizer       2.1.1
# comm                     0.1.2
# debugpy                  1.6.4
# decorator                5.1.1
# defusedxml               0.7.1
# entrypoints              0.4
# et-xmlfile               1.1.0
# exceptiongroup           1.0.4
# executing                1.2.0
# fastjsonschema           2.16.2
# filelock                 3.8.2
# firebase-admin           5.4.0
# ...

# %%
GOOGLE_MAPS_API_KEY = os.environ['GOOGLE_MAPS_API_KEY']
api_cliet = ApiClient(api_key=os.environ['GOOGLE_MAPS_API_KEY'])
response = api_cliet.google_maps_search(
    'Padel in France',
    language='en',
    region='fr',
    limit=10
)
