# %%
from dotenv import load_dotenv
load_dotenv()
import os
import requests
import pandas as pd
import json
GOOGLE_MAPS_API_KEY = os.environ.get('GOOGLE_MAPS_API_KEY')
print(GOOGLE_MAPS_API_KEY)
df = None
# Out:
# AIzaSyBomy3MbbACalcJCph_RzRhtYfHILMKlAo

# %%
vInput="Padel in France"
vInput=vInput.replace(" ","%20")
print(vInput)
vFields="formatted_address,name,rating,opening_hours"
vFields=vFields.replace(",","%2C")
print(vFields)
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.302912%2C5.4329344&radius=10000&keyword=padel&key="+GOOGLE_MAPS_API_KEY

print(url)
# Out:
# Padel%20in%20France
# formatted_address%2Cname%2Crating%2Copening_hours
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=43.302912%2C5.4329344&radius=10000&keyword=padel&key=AIzaSyBomy3MbbACalcJCph_RzRhtYfHILMKlAo

# %%
payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 43.30179589999999,
#                "lng" : 5.4927682
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 43.30331652989272,
#                   "lng" : 5.494323679892721
#                },
#                "southwest" : {
#                   "lat" : 43.30061687010728,
#                   "lng" : 5.491624020107277
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Padel Marseille",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 407,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/115233448520061679810\"\u003ePadel Marseille\u003c/a\u003e"
#                ],
#                "photo_reference" : "ARywPAKu7SAkIjxFbd_rtNCCZ1Ra9KQWA0ObaaIQumn8Y_Q0wfqHUdEPjPSAyknx8t_MCK-doJlui2JtarcP-9-4esx01FygJS6xJG3fH0wRYVrF3OVQqkgW0WssK8398xuwHw_Z2gYEFxP4-ZmLB6TX9TcGD-C9pu2y9897j-QGv-0QnNra",
#                "width" : 680
#             }
#          ],
#          "place_id" : "ChIJC9kcJjq8yRIRZZ3S-h_pSrA",
#          "plus_code" : {
#             "compound_code" : "8F2V+P4 Marseille",
#             "global_code" : "8FM78F2V+P4"
#          },
#          "rating" : 4.7,
#          "reference" : "ChIJC9kcJjq8yRIRZZ3S-h_pSrA",
#          "scope" : "GOOGLE",
#          "types" : [ "point_of_interest", "establishment" ],
#          "user_ratings_total" : 43,
#          "vicinity" : "92 Chem. des Accates, Marseille"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 43.3396911,
#                "lng" : 5.4599962
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 43.34104092989272,
#                   "lng" : 5.461346029892722
#                },
#                "southwest" : {
#                   "lat" : 43.33834127010728,
#                   "lng" : 5.458646370107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Padel Bocage",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 598,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/110518810744222480684\"\u003ePadel Bocage\u003c/a\u003e"
#                ],
#                "photo_reference" : "ARywPAKRiNaMCxr6TyG-0Ek5avsrZriSoGwnub5jQttbHxae5OXuiZ-HDS9j-Ajv17y6bxmVgG1Hp14uN6pTaEgGEcYzMy_16Y4I4eis7ZbalDsU8eQbTBmiJTDdqbQGJaNGNX3-Lqk29LH0Qm8t_2kn87EgolR_wJt4n6boKIMXrPDo05bt",
#                "width" : 1066
#             }
#          ],
#          "place_id" : "ChIJC84nYxa-yRIRqynnuNeSJLY",
#          "plus_code" : {
#             "compound_code" : "8FQ5+VX Plan-de-Cuques",
#             "global_code" : "8FM78FQ5+VX"
#          },
#          "rating" : 4.8,
#          "reference" : "ChIJC84nYxa-yRIRqynnuNeSJLY",
#          "scope" : "GOOGLE",
#          "types" : [ "point_of_interest", "establishment" ],
#          "user_ratings_total" : 52,
#          "vicinity" : "All. Pierre de Coubertin, Plan-de-Cuques"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 43.23013539999999,
#                "lng" : 5.5344393
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 43.23137417989273,
#                   "lng" : 5.535686829892722
#                },
#                "southwest" : {
#                   "lat" : 43.22867452010728,
#                   "lng" : 5.532987170107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Sporting Club Cassis Tennis & Padel",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 4608,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/112838758866857294242\"\u003eflorence\u003c/a\u003e"
#                ],
#                "photo_reference" : "ARywPAIIgHaU5Z7J2-iqJ7ukSNhuFSneuvXriFnffJNhCe6XAh8Nub9GEIZXYaoP9plcK0gx2ehI8WaHNQ8nzcFWfF494uv9xNgbU7UVKkgfjXpHe4so0eWtNh_7cudD4BElcjlmoV8abq0-LIknYiVN4X0lhw6zcJD8DdSQs7Hww9YYebGj",
#                "width" : 2592
#             }
#          ],
#          "place_id" : "ChIJ8_NOpFq7yRIRbbnwJwo8j4I",
#          "plus_code" : {
#             "compound_code" : "6GJM+3Q Cassis",
#             "global_code" : "8FM76GJM+3Q"
#          },
#          "rating" : 4.6,
#          "reference" : "ChIJ8_NOpFq7yRIRbbnwJwo8j4I",
#          "scope" : "GOOGLE",
#          "types" : [ "point_of_interest", "establishment" ],
#          "user_ratings_total" : 33,
#          "vicinity" : "Av. des Gorguettes, Cassis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 43.23818869999999,
#                "lng" : 5.430134799999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 43.23968412989272,
#                   "lng" : 5.431534029892722
#                },
#                "southwest" : {
#                   "lat" : 43.23698447010727,
#                   "lng" : 5.428834370107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Luminy Tennis Academy | Tennis & Padel",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/105279793526577327141\"\u003eTennis Academy de Luminy\u003c/a\u003e"
#                ],
#                "photo_reference" : "ARywPALd4Pf1ZbSzwxFPIkpq0hXDeRn8cPJBMlzJUCzjGZ177BcYzll4uegXqT7qczLe6FSzaUIjSAF1kGsb_4iJjBPaw9zWSwXEMVs21hNrC0HAPFFJ5E9pn-q6vdTETZGy7Mbyf59OrPG1PApRF22STzQWINEDGWsMQv4qVDMymncp1p9R",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJ18rX31W4yRIR-HA9WWY2u4I",
#          "plus_code" : {
#             "compound_code" : "6CQJ+73 Marseille",
#             "global_code" : "8FM76CQJ+73"
#          },
#          "rating" : 4.5,
#          "reference" : "ChIJ18rX31W4yRIR-HA9WWY2u4I",
#          "scope" : "GOOGLE",
#          "types" : [ "point_of_interest", "establishment" ],
#          "user_ratings_total" : 73,
#          "vicinity" : "Rue Henri Cochet, Marseille"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 43.3020523,
#                "lng" : 5.492686
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 43.30352972989272,
#                   "lng" : 5.494086829892721
#                },
#                "southwest" : {
#                   "lat" : 43.30083007010728,
#                   "lng" : 5.491387170107277
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Tennis Park de Marseille | Tennis & Padel",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 1536,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/103719255533473552354\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "ARywPAJn3SpbM75uV3NxAIKCSn7cfuddCkzeN8p-K5ZPmKok5G9nbmrtgFBJbQGDflMsX9dDCyagycizdYVB2fFqxQYepj24NctTRPXMPQ895O6SFmohXHGzHdq4CvXWI8P8LRTRyuj9OFZnAGapFHaikRqfQA32JJj9mr2yrwIySqAGU-RY",
#                "width" : 2048
#             }
#          ],
#          "place_id" : "ChIJFec6JTq8yRIR3RPgm0lbw9E",
#          "plus_code" : {
#             "compound_code" : "8F2V+R3 Marseille",
#             "global_code" : "8FM78F2V+R3"
#          },
#          "rating" : 4.4,
#          "reference" : "ChIJFec6JTq8yRIR3RPgm0lbw9E",
#          "scope" : "GOOGLE",
#          "types" : [ "point_of_interest", "establishment" ],
#          "user_ratings_total" : 179,
#          "vicinity" : "92 Chem. des Accates, Marseille"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 43.21143,
#                "lng" : 5.516852
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 43.21273052989272,
#                   "lng" : 5.518258979892722
#                },
#                "southwest" : {
#                   "lat" : 43.21003087010727,
#                   "lng" : 5.515559320107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "ASSOCIATION TCP PADEL",
#          "place_id" : "ChIJb-5kWGO7yRIRN0HnY7bk-Ac",
#          "plus_code" : {
#             "compound_code" : "6G68+HP Cassis",
#             "global_code" : "8FM76G68+HP"
#          },
#          "rating" : 0,
#          "reference" : "ChIJb-5kWGO7yRIRN0HnY7bk-Ac",
#          "scope" : "GOOGLE",
#          "types" : [ "point_of_interest", "establishment" ],
#          "user_ratings_total" : 0,
#          "vicinity" : "MIOU, TENNIS CLUB DE LA PRESQU'ILE, QUARTIER PORT, Cassis"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 43.33370070000001,
#                "lng" : 5.370389599999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 43.33498117989273,
#                   "lng" : 5.371767629892721
#                },
#                "southwest" : {
#                   "lat" : 43.33228152010729,
#                   "lng" : 5.369067970107277
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Le 13 by Puma - Foot en salle - Marseille",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 2560,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/109220524574147916419\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "ARywPALRmDAXfSruz-mWRqHciFfpi1qbkL-_a_yFLWwk-dVPGzWWRhJsfSk9tqllj_nooIjBbK_QwMOfR6DzavWF6fOYk35aOKiRiWp_to72r_6fv7NsT0Yi3-cnojRv75YZoKkv563QDt0Q59Vb5UYE7z9VFEMlbaWzMV6RSsaykAh3dR_7",
#                "width" : 1332
#             }
#          ],
#          "place_id" : "ChIJR62kUm_ByRIRDnGQqGCeUVQ",
#          "plus_code" : {
#             "compound_code" : "89MC+F5 Marseille",
#             "global_code" : "8FM789MC+F5"
#          },
#          "rating" : 4.5,
#          "reference" : "ChIJR62kUm_ByRIRDnGQqGCeUVQ",
#          "scope" : "GOOGLE",
#          "types" : [ "point_of_interest", "establishment" ],
#          "user_ratings_total" : 278,
#          "vicinity" : "18 Bd Frédéric Sauvage, Marseille"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 43.2678954,
#                "lng" : 5.380777699999999
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 43.26918677989272,
#                   "lng" : 5.381964729892721
#                },
#                "southwest" : {
#                   "lat" : 43.26648712010728,
#                   "lng" : 5.379265070107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Tennis Club de Marseille | Tennis",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 2006,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/117956666474404812208\"\u003eLES BLAGUES DE FREDO\u003c/a\u003e"
#                ],
#                "photo_reference" : "ARywPAIl1cK1Z5cUk5mUoZ4hIzMbk1aC8Z-mf5mxzuoSHiNINH_WgEjUjsx4PKGhkp59UprOirkNuyNLyREbG5fjlLttfS9Iqrq8CuNPDAYVq4N0eBTFq8aw43bgCIsq3WAPQfKT3Gap7wDMSDjXDBQgBDqkSro8OVmwEU-zFnQYQDHZWvxS",
#                "width" : 4128
#             }
#          ],
#          "place_id" : "ChIJQSnIUETHyRIRGB1bOvevHew",
#          "plus_code" : {
#             "compound_code" : "799J+58 Marseille",
#             "global_code" : "8FM7799J+58"
#          },
#          "rating" : 4.1,
#          "reference" : "ChIJQSnIUETHyRIRGB1bOvevHew",
#          "scope" : "GOOGLE",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 145,
#          "vicinity" : "10 Bd de Tunis, Marseille"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 43.2997436,
#                "lng" : 5.427905
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 43.30111442989272,
#                   "lng" : 5.429105529892723
#                },
#                "southwest" : {
#                   "lat" : 43.29841477010728,
#                   "lng" : 5.426405870107279
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "TENNIS CLUB LA FOURRAGERE ASPTT",
#          "photos" : [
#             {
#                "height" : 2592,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/111385962634474404668\"\u003eTCA casanova\u003c/a\u003e"
#                ],
#                "photo_reference" : "ARywPAImJLtO99M4G-pzeb7U_IXh3LOjyuWEhLWoFqUoIL3A61SKcX1YHT6mclomacv0Jj5v-cIdURDAoXODHgM3foAAFY3zb6sA9ze8AVz6hrOmhlIav1E6jXVXH4IkjxzzPEnEUZE0pYv6CDI1RwUG5iX-VAmoL2yvfVTHdPjT0MNNBAYr",
#                "width" : 4608
#             }
#          ],
#          "place_id" : "ChIJx1cLURi_yRIRFqQK96cn_bM",
#          "plus_code" : {
#             "compound_code" : "7CXH+V5 Marseille",
#             "global_code" : "8FM77CXH+V5"
#          },
#          "rating" : 4.4,
#          "reference" : "ChIJx1cLURi_yRIRFqQK96cn_bM",
#          "scope" : "GOOGLE",
#          "types" : [ "point_of_interest", "establishment" ],
#          "user_ratings_total" : 159,
#          "vicinity" : "Marseille"
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 43.28035000000001,
#                "lng" : 5.435051
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 43.28171907989271,
#                   "lng" : 5.436385529892722
#                },
#                "southwest" : {
#                   "lat" : 43.27901942010727,
#                   "lng" : 5.433685870107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "T.C QUEIREL ST-LOUP",
#          "place_id" : "ChIJ1zgDYqK_yRIRxiZn7zPEFzg",
#          "plus_code" : {
#             "compound_code" : "7CJP+42 Marseille",
#             "global_code" : "8FM77CJP+42"
#          },
#          "rating" : 0,
#          "reference" : "ChIJ1zgDYqK_yRIRxiZn7zPEFzg",
#          "scope" : "GOOGLE",
#          "types" : [ "point_of_interest", "establishment" ],
#          "user_ratings_total" : 0,
#          "vicinity" : "88 Bd Queirel, Marseille"
#       }
#    ],
#    "status" : "OK"
# }

# %%
if df is not None:
    google_dict = json.loads(response.text)
    business_status = []
    lat = []
    lng = []
    name = []
    vicinity = []
    if len(google_dict['results'])==0:
        print('No results')
    else:
        for i in range(len(google_dict['results'])-1):
            name.append(google_dict['results'][i]['name'])
            vicinity.append(google_dict['results'][i]['vicinity'])
            business_status.append(google_dict['results'][i]['business_status'])
            lat.append(google_dict['results'][i]['geometry']['location']['lat'])
            lng.append(google_dict['results'][i]['geometry']['location']['lng'])
            
    df = pd.DataFrame(name, columns=['name'])
    df['address']=vicinity
    df['business_status']=business_status
    df['latitude']=lat
    df['longitude']=lng
    print(df.head())
# Out:
#                                         name  \
# 0                            Padel Marseille
# 1                               Padel Bocage
# 2        Sporting Club Cassis Tennis & Padel
# 3     Luminy Tennis Academy | Tennis & Padel
# 4  Tennis Park de Marseille | Tennis & Padel
#
#                                     address business_status   latitude  \
# 0           92 Chem. des Accates, Marseille     OPERATIONAL  43.301796
# 1  All. Pierre de Coubertin, Plan-de-Cuques     OPERATIONAL  43.339691
# 2                Av. des Gorguettes, Cassis     OPERATIONAL  43.230135
# 3               Rue Henri Cochet, Marseille     OPERATIONAL  43.238189
# 4           92 Chem. des Accates, Marseille     OPERATIONAL  43.302052
#
#    longitude
# 0   5.492768
# 1   5.459996
# 2   5.534439
# 3   5.430135
# 4   5.492686
