# %%
# !pip3 install firebase_admin
# !pip install google.cloud
# Out:
# Requirement already satisfied: firebase_admin in /opt/homebrew/lib/python3.10/site-packages (5.4.0)
# Requirement already satisfied: cachecontrol>=0.12.6 in /opt/homebrew/lib/python3.10/site-packages (from firebase_admin) (0.12.11)
# Requirement already satisfied: google-cloud-firestore>=2.1.0 in /opt/homebrew/lib/python3.10/site-packages (from firebase_admin) (2.7.0)
# Requirement already satisfied: google-api-core[grpc]<3.0.0dev,>=1.22.1 in /opt/homebrew/lib/python3.10/site-packages (from firebase_admin) (2.10.1)
# Requirement already satisfied: google-api-python-client>=1.7.8 in /opt/homebrew/lib/python3.10/site-packages (from firebase_admin) (2.63.0)
# Requirement already satisfied: google-cloud-storage>=1.37.1 in /opt/homebrew/lib/python3.10/site-packages (from firebase_admin) (2.5.0)
# Requirement already satisfied: msgpack>=0.5.2 in /opt/homebrew/lib/python3.10/site-packages (from cachecontrol>=0.12.6->firebase_admin) (1.0.4)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.10/site-packages (from cachecontrol>=0.12.6->firebase_admin) (2.28.1)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.20.1 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (4.21.7)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (2.12.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (1.56.4)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (1.49.1)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (1.49.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /opt/homebrew/lib/python3.10/site-packages (from google-api-python-client>=1.7.8->firebase_admin) (0.20.4)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/homebrew/lib/python3.10/site-packages (from google-api-python-client>=1.7.8->firebase_admin) (4.1.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /opt/homebrew/lib/python3.10/site-packages (from google-api-python-client>=1.7.8->firebase_admin) (0.1.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /opt/homebrew/lib/python3.10/site-packages (from google-cloud-firestore>=2.1.0->firebase_admin) (2.3.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /opt/homebrew/lib/python3.10/site-packages (from google-cloud-firestore>=2.1.0->firebase_admin) (1.22.1)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /opt/homebrew/lib/python3.10/site-packages (from google-cloud-storage>=1.37.1->firebase_admin) (2.4.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (1.16.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/homebrew/lib/python3.10/site-packages (from google-resumable-media>=2.3.2->google-cloud-storage>=1.37.1->firebase_admin) (1.5.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/homebrew/lib/python3.10/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client>=1.7.8->firebase_admin) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests->cachecontrol>=0.12.6->firebase_admin) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests->cachecontrol>=0.12.6->firebase_admin) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests->cachecontrol>=0.12.6->firebase_admin) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests->cachecontrol>=0.12.6->firebase_admin) (3.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/homebrew/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<3.0.0dev,>=1.22.1->firebase_admin) (0.4.8)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: google.cloud in /opt/homebrew/lib/python3.9/site-packages (0.34.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
# !pip3 install google-cloud-core
# !pip3 install google-cloud-firestore
# Out:
# Requirement already satisfied: google-cloud-core in /opt/homebrew/lib/python3.10/site-packages (2.3.2)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /opt/homebrew/lib/python3.10/site-packages (from google-cloud-core) (2.12.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.6 in /opt/homebrew/lib/python3.10/site-packages (from google-cloud-core) (2.10.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.6->google-cloud-core) (1.56.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.6->google-cloud-core) (2.28.1)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.20.1 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.6->google-cloud-core) (4.21.7)
# Requirement already satisfied: six>=1.9.0 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-core) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-core) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-core) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-core) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/homebrew/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-core) (0.4.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.6->google-cloud-core) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.6->google-cloud-core) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.6->google-cloud-core) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.6->google-cloud-core) (3.4)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Requirement already satisfied: google-cloud-firestore in /opt/homebrew/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /opt/homebrew/lib/python3.10/site-packages (from google-cloud-firestore) (2.3.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /opt/homebrew/lib/python3.10/site-packages (from google-cloud-firestore) (1.22.1)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in /opt/homebrew/lib/python3.10/site-packages (from google-cloud-firestore) (2.10.1)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.19.0 in /opt/homebrew/lib/python3.10/site-packages (from google-cloud-firestore) (4.21.7)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (2.12.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (1.56.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (2.28.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (1.49.1)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /opt/homebrew/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (1.49.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (4.9)
# Requirement already satisfied: six>=1.9.0 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (5.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (2022.9.24)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/homebrew/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-firestore) (0.4.8)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# !pip install google-cloud-firestore
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: google-cloud-firestore in /opt/homebrew/lib/python3.9/site-packages (2.5.3)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.19.0 in /opt/homebrew/lib/python3.9/site-packages (from google-cloud-firestore) (3.20.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.4.1 in /opt/homebrew/lib/python3.9/site-packages (from google-cloud-firestore) (2.3.1)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /opt/homebrew/lib/python3.9/site-packages (from google-cloud-firestore) (2.8.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.20.5 in /opt/homebrew/lib/python3.9/site-packages (from google-cloud-firestore) (1.20.6)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/homebrew/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (1.56.3)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /opt/homebrew/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (2.8.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/homebrew/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (2.27.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/homebrew/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (1.47.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /opt/homebrew/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (1.47.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.9/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.9/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/homebrew/lib/python3.9/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (5.2.0)
# Requirement already satisfied: six>=1.9.0 in /opt/homebrew/lib/python3.9/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/homebrew/lib/python3.9/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (2.0.12)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/homebrew/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-firestore) (0.4.8)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %%
# !pip3 install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/homebrew/lib/python3.10/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /opt/homebrew/lib/python3.10/site-packages (from openpyxl) (1.1.0)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/Users/raph/Documents/Zeep/App/zeepwebapp-6535a41e25af.json"

# %%
import firebase_admin
from google.cloud import firestore
from datetime import datetime
from datetime import date
import datetime
from datetime import timezone as tz
from datetime import *
import pytz
import pandas as pd
#from exponent_server_sdk import (
#    DeviceNotRegisteredError,
#    PushClient,
#    PushMessage,
#    PushServerError,
#    PushTicketError,
#)

#from requests.exceptions import ConnectionError, HTTPError

#def send_push_message(token, message, extra=None):
#    response = PushClient().publish(
#            PushMessage(to=token,
#                        body=message,
#                        data=extra))

db = firestore.Client()

df = pd.read_excel (r'/Users/raph/Documents/Zeep/Restaurants/Poke Bar Richer/Menu poke bar richer.xlsx',sheet_name='big_cat')
dfCategories = pd.read_excel (r'/Users/raph/Documents/Zeep/Restaurants/Poke Bar Richer/Menu poke bar richer.xlsx',sheet_name='categories')
dfArticles = pd.read_excel (r'/Users/raph/Documents/Zeep/Restaurants/Poke Bar Richer/Menu poke bar richer.xlsx',sheet_name='articles')

for index, row in dfArticles.iterrows():
    print(row['name'])
    

def createBigCat():
    bigCat = db.collection(u'bigCat')
    #docs = slots.stream()
    
    for index, row in df.iterrows():
        print(row['name'])
        data = {
                u'name': row['name'],
                u'restaurantID': row['restaurantID'],
                u'category': row['category'],
                u'rank': row['rank'],
            }
        db.collection(u'bigCat').document().set(data)
            #docId = slots.document(doc.id)
            #docId.delete()
        #for doc in docs:
            #print(day)
        #    docId = slots.document(doc.id)
        
        #docId.update({'FirstName':'Raph'})
        #    date = u'{}'.format(doc.to_dict()['date'])
        #date_obj = datetime.strptime(date, "%d/%m/%y")
            #if date==day:
                #docId.delete()
                #print(day)
                
def createCategories():
    categories = db.collection(u'categories')
    #docs = slots.stream()
    
    for index, row in dfCategories.iterrows():
        print(row['name'])
        data = {
                u'name': row['name'],
                u'restaurant': row['restaurant'],
                u'type': row['type'],
                u'rank': row['rank'],
            }
        db.collection(u'categories').document().set(data)
            #docId = slots.document(doc.id)
            #docId.delete()
        #for doc in docs:
            #print(day)
        #    docId = slots.document(doc.id)
        
        #docId.update({'FirstName':'Raph'})
        #    date = u'{}'.format(doc.to_dict()['date'])
        #date_obj = datetime.strptime(date, "%d/%m/%y")
            #if date==day:
                #docId.delete()
                #print(day)

def createArticles():
    articles = db.collection(u'articles')
    #docs = slots.stream()
    
    for index, row in dfArticles.iterrows():
        print(row['name'])
        if row['description'] == "nan":
            data = {
                    u'name': str(row['name']),
                    u'description': str(""),
                    u'category': str(row['category']),
                    u'dispo': row['dispo'],
                    u'legal_age': row['legal_age'],
                    u'price': row['price'],
                    u'restaurant': str(row['restaurant']),
                    u'cuisson': row['cuisson'],
                    u'rank': row['rank'],
                }
        else:
            data = {
                    u'name': str(row['name']),
                    u'description': str(row['description']),
                    u'category': str(row['category']),
                    u'dispo': row['dispo'],
                    u'legal_age': row['legal_age'],
                    u'price': row['price'],
                    u'restaurant': str(row['restaurant']),
                    u'cuisson': row['cuisson'],
                    u'rank': row['rank'],
                }
        db.collection(u'articles').document().set(data)
            #docId = slots.document(doc.id)
            #docId.delete()
        #for doc in docs:
            #print(day)
        #    docId = slots.document(doc.id)
        
        #docId.update({'FirstName':'Raph'})
        #    date = u'{}'.format(doc.to_dict()['date'])
        #date_obj = datetime.strptime(date, "%d/%m/%y")
            #if date==day:
                #docId.delete()
                #print(day)

def deleteArticles():
    print("Hello")
    articles = db.collection(u'articles')
    docs = articles.where(u'restaurant', u'==', "la_riviera").stream()
    for doc in docs: 
        if u'{}'.format(doc.to_dict()['category'])=="Plats 🍝":
            docId = articles.document(doc.id)
            docId.delete()

def correctArticles():
    print("Hello")
    articles = db.collection(u'articles')
    docs = articles.where(u'description', u'==', "nan").stream()
    for doc in docs:
        docId = articles.document(doc.id)
        docId.update({'description':''})
# Out:
# Coca-Cola
# Coca-Cola Zero
# Eau plate
# Ice tea
# Jus de pomme
# San Pellegrino
# San Pellegrino limonata
# Poké Daurade Maui
# Poké Poulet Hanalei
# Poké Saumon Oahu
# Poké Thon Honolulu
# Poké Tofu Mahalo
# Poké Saumon Kauai
# Veggie Bowl
# Poké Daurade Maui
# Poké Poulet Hanalei
# Poké Saumon Kauai
# Poké saumon Oahu
# Poké Thon Honolulu
# Poké Tofu Mahalo
# Veggie Bowl
# Poké Daurade Maui
# Poké Poulet Hanalei
# Poké Saumon Kauai
# Poké saumon Oahu
# Poké Thon Honolulu
# Poké Tofu Mahalo
# Veggie Bowl
# Poké Daurade Maui
# Poké Poulet Hanalei
# Poké Saumon Kauai
# Poké saumon Oahu
# Poké Thon Honolulu
# Poké Tofu Mahalo
# Veggie Bowl
# Poké Daurade Maui
# Poké Poulet Hanalei
# Poké Saumon Kauai
# Poké saumon Oahu
# Poké Thon Honolulu
# Poké Tofu Mahalo
# Veggie Bowl
# Poké Daurade Maui
# Poké Poulet Hanalei
# Poké Saumon Kauai
# Poké saumon Oahu
# Poké Thon Honolulu
# Poké Tofu Mahalo
# Veggie Bowl

# %%
createBigCat()
#createCategories()
createArticles()
correctArticles()
# Out:
# Mini poké bowl signature
# Poké bowl signature
# Menu Poké + boisson (à définir sur place)
# Menu Mini poké + boisson (à définir sur place)
# Menu Poké + boisson + dessert (à définir sur place)
# Menu Mini poké + boisson + dessert (à définir sur place)
# Boissons 🍹
# Coca-Cola
# Coca-Cola Zero
# Eau plate
# Ice tea
# Jus de pomme
# San Pellegrino
# San Pellegrino limonata
# Poké Daurade Maui
# Poké Poulet Hanalei
# Poké Saumon Oahu
# Poké Thon Honolulu
# Poké Tofu Mahalo
# Poké Saumon Kauai
# Veggie Bowl
# Poké Daurade Maui
# Poké Poulet Hanalei
# Poké Saumon Kauai
# Poké saumon Oahu
# Poké Thon Honolulu
# Poké Tofu Mahalo
# Veggie Bowl
# Poké Daurade Maui
# Poké Poulet Hanalei
# Poké Saumon Kauai
# Poké saumon Oahu
# Poké Thon Honolulu
# Poké Tofu Mahalo
# Veggie Bowl
# Poké Daurade Maui
# Poké Poulet Hanalei
# Poké Saumon Kauai
# Poké saumon Oahu
# Poké Thon Honolulu
# Poké Tofu Mahalo
# Veggie Bowl
# Poké Daurade Maui
# Poké Poulet Hanalei
# Poké Saumon Kauai
# Poké saumon Oahu
# Poké Thon Honolulu
# Poké Tofu Mahalo
# Veggie Bowl
# Poké Daurade Maui
# Poké Poulet Hanalei
# Poké Saumon Kauai
# Poké saumon Oahu
# Poké Thon Honolulu
# Poké Tofu Mahalo
# Veggie Bowl
# Hello
